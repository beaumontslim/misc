# %% [markdown]
# <a href="https://colab.research.google.com/github/beaumontslim/misc/blob/main/classifier_pickle_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pickle

#download saved pickles and use them to make predictions on new data

# %%
# !ls
# Out:
# sample_data

# %%
# !wget https://github.com/futurexskill/ml-model-deployment/raw/main/classifier.pickle
# Out:
# --2021-03-15 04:31:22--  https://github.com/futurexskill/ml-model-deployment/raw/main/classifier.pickle
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/classifier.pickle [following]
# --2021-03-15 04:31:22--  https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/classifier.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2113 (2.1K) [application/octet-stream]
# Saving to: ‘classifier.pickle’
#
# classifier.pickle   100%[===================>]   2.06K  --.-KB/s    in 0s
#
# ...

# %%
# !wget https://github.com/futurexskill/ml-model-deployment/raw/main/sc.pickle
# Out:
# --2021-03-15 04:32:14--  https://github.com/futurexskill/ml-model-deployment/raw/main/sc.pickle
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/sc.pickle [following]
# --2021-03-15 04:32:14--  https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/sc.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 502 [application/octet-stream]
# Saving to: ‘sc.pickle’
#
# sc.pickle           100%[===================>]     502  --.-KB/s    in 0s
#
# 2021-03-15 04:32:14 (5.10 MB/s) - ‘sc.pickle’ saved [502/502]

# %%
# !ls
# Out:
# classifier.pickle  sample_data	sc.pickle

# %%
classifier_colab = pickle.load(open('classifier.pickle','rb'))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator KNeighborsClassifier from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
scaler_colab = pickle.load(open('sc.pickle','rb'))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
new_prediction1 = classifier_colab.predict(scaler_colab.transform((np.array([[42,25000]]))))

# %%
new_prediction1
# Out:
# array([0])

# %%
new_proba1 = classifier_colab.predict_proba(scaler_colab.transform((np.array([[42,25000]]))))[:,1]

# %%
new_proba1
# Out:
# array([0.2])
