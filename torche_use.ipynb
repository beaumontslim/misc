# %% [markdown]
# <a href="https://colab.research.google.com/github/beaumontslim/misc/blob/main/torche_use.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls

# !wget https://github.com/futurexskill/ml-model-deployment/raw/main/customer_buy_state_dict_v1.zip

# !ls

# !unzip customer_buy_state_dict_v1.zip

# !ls

#!wget https://github.com/futurexskill/ml-model-deployment/raw/main/sc.pickle

import pickle

local_scaler = pickle.load(open('sc.pickle.2','rb'))

import torch
import torch.nn as nn
from torch.nn import functional as F
import numpy as np

input_size=2
output_size=2
hidden_size=10

class Net(nn.Module):
   def __init__(self):
       super(Net, self).__init__()
       self.fc1 = torch.nn.Linear(input_size, hidden_size)
       self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
       self.fc3 = torch.nn.Linear(hidden_size, output_size)


   def forward(self, X):
       X = torch.relu((self.fc1(X)))
       X = torch.relu((self.fc2(X)))
       X = self.fc3(X)

       return F.log_softmax(X,dim=1)

new_predictor2 = Net()

new_predictor2.load_state_dict(torch.load('customer_buy_state_dict'))

y_cust_42_50000 = new_predictor2(torch.from_numpy(local_scaler.transform(np.array([[40,20000]]))).float())
y_cust_42_50000
# Out:
# customer_buy_state_dict		customer_buy_state_dict.zip.1  sc.pickle.1
# customer_buy_state_dict_v1.zip	sample_data		       sc.pickle.2
# customer_buy_state_dict.zip	sc.pickle
# --2021-03-16 23:35:53--  https://github.com/futurexskill/ml-model-deployment/raw/main/customer_buy_state_dict_v1.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/customer_buy_state_dict_v1.zip [following]
# --2021-03-16 23:35:53--  https://raw.githubusercontent.com/futurexskill/ml-model-deployment/main/customer_buy_state_dict_v1.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1660 (1.6K) [application/zip]
# Saving to: ‘customer_buy_state_dict_v1.zip.1’
#
# customer_buy_state_ 100%[===================>]   1.62K  --.-KB/s    in 0s
#
# 2021-03-16 23:35:53 (39.0 MB/s) - ‘customer_buy_state_dict_v1.zip.1’ saved [1660/1660]
#
# customer_buy_state_dict		  customer_buy_state_dict.zip	 sc.pickle
# customer_buy_state_dict_v1.zip	  customer_buy_state_dict.zip.1  sc.pickle.1
# customer_buy_state_dict_v1.zip.1  sample_data			 sc.pickle.2
# Archive:  customer_buy_state_dict_v1.zip
# replace customer_buy_state_dict? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# customer_buy_state_dict		  customer_buy_state_dict.zip	 sc.pickle
# customer_buy_state_dict_v1.zip	  customer_buy_state_dict.zip.1  sc.pickle.1
# customer_buy_state_dict_v1.zip.1  sample_data			 sc.pickle.2
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# tensor([[-0.1102, -2.2600]], grad_fn=<LogSoftmaxBackward>)
